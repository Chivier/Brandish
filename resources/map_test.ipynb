# %%
import tifffile as tiff
import matplotlib.pyplot as plt
import rasterio
import numpy as np
import matplotlib

tfile = tiff.imread('data.tif')
tfile.shape
tiff.imshow(tfile)
# Out:
# (<Figure size 988.8x604.8 with 2 Axes>,
#  <AxesSubplot:>,
#  <matplotlib.image.AxesImage at 0x7f7a04519c40>)

# %%
dataset = rasterio.open('data.tif')
band1 = dataset.read(1)
print(dataset.bounds)
testx, testy = dataset.index(12.47, 41.93)
print(testx, testy)
print(band1[testx, testy])
# Out:
# BoundingBox(left=12.34986111111111, bottom=41.80013888888889, right=12.649861111111111, top=42.00013888888889)
# 252 432
# 24
